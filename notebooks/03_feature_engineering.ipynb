# %% [markdown]
# # 03 — Feature Engineering & Imbalance Strategies
#
# New features (time-of-day, amount bucketing, etc.) and imbalance handling
# (SMOTE, class weighting, undersampling). Document tradeoffs.

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
from fraud.data_loader import load_raw

df = load_raw()

# %%
# Engineer Hour from Time
df["Hour"] = (df["Time"] // 3600) % 24

# Drop low-signal features identified in EDA
low_signal = ["V13", "V15", "V22", "V23", "V24", "V25", "V26", "V28"]
df = df.drop(columns=low_signal)

# Drop original Time now that we have Hour (optional - your call)
df = df.drop(columns=["Time"])

df.shape
